# %%
# TAREAS DE LOS MÓDULOS DE CNN Y RNN - MIAX9
# Para cada uno de los siguientes ejercicios entregar un fichero en ipython notebook  (.ipynb).
# En cada fichero tenéis que solucionar un ejercicio distinto, es importante que comentéis la
# solución que habéis realizado y los resultados obtenidos.
# El código ha de ser compilable desde Google Colab (utilizando el entorno de Colab), y no
# ha de contener errores. En los casos en los que se pide entrenar un modelo razona sobre
# la evolución del error de entrenamiento y de validación durante el entrenamiento.
# La práctica deberá realizarse de manera individual y debe entregarse en la plataforma de
# Instituto BME.

# %%
# 8.- Diseña un modelo en Keras que utilice capas convolucionales 2D y la capa GDN (la
# tenéis en el diccionario de Keras / Custom) para el mismo conjunto de datos del ejercicio 6.

# %%
#from __future__ import absolute_import, division, print_function, unicode_literals
# Installa TensorFlow
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv1D, LSTM, GRU, MaxPooling1D, Conv2D, MaxPooling2D, Dropout, Bidirectional, Reshape, Activation, LSTM, SimpleRNN, GRU

import numpy as np
import pandas as pd

from tensorflow import keras


import tensorflow as tf
from tensorflow.keras.datasets import mnist, fashion_mnist, cifar10

#import keras
from tensorflow.keras.layers import Layer, Conv2D, AveragePooling2D, Flatten, Dense, Softmax, ReLU
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.constraints import NonNeg

import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
import random

from scipy import signal

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2.11.0

# %%
def datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model):
    salida=np.zeros((17))
    #trainableParams
    salida[0] = np.sum([np.prod(v.get_shape()) for v in model.trainable_weights])
    #nonTrainableParams
    salida[1] = np.sum([np.prod(v.get_shape()) for v in model.non_trainable_weights])
    #totalParams
    salida[2] = salida[0] + salida[1]
    
    #Train
    score = model.evaluate(x_train, t_train)
    salida[3] = score[0]
    salida[4] = score[1]
    y_hat = model.predict(x_train)
    # El  error de la predicion en train
    salida[5] = np.mean(abs(y_hat[:,0]-t_train))
    # La media de error en la prediccion en train 
    salida[6] =np.mean(np.abs(t_train))
    
    #Test
    score = model.evaluate(x_test, t_test)
    salida[7] = score[0]
    salida[8] = score[1]
    y_hat_test = model.predict(x_test)
    # El  error de la predicion en test
    salida[9] = np.mean(abs(y_hat_test[:,0]-t_test))
    # La media de error en la prediccion en test
    salida[10] = np.mean(np.abs(t_test))
    
    # numero de datos de entrada en train
    salida[11] = x_train.shape[0]
    #dimensiones de la entrada
    salida[12] =len(x_train.shape)
    # valor de la dimension 1 de la entrada
    if salida[12] >= 1:
        salida[13] = x_train.shape[0]
    # valor de la dimension 2 de la entrada
    if salida[12] >= 2:
        salida[14] = x_train.shape[1]
    # valor de la dimension 3 de la entrada
    if salida[12] >= 3:
        salida[15] = x_train.shape[2]
    # valor de la dimension 4 de la entrada
    if salida[12] >= 4:
        salida[16] = x_train.shape[3]
    
    print(len(salida))
    
    import pandas as pd 
    df = pd.read_csv ('metricas.csv', index_col=0) 
    print(df.shape)
    df[model_title] = salida
    df.to_csv('metricas.csv') 

    return salida, df

# %%
class GDN(Layer):
    def __init__(self, 
                 filter_shape = (3,3), 
                 **kwargs):
      
        self.filter_shape = filter_shape

        super(GDN, self).__init__(**kwargs)

    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.beta = self.add_weight(name = 'beta', 
                                    shape = (input_shape.as_list()[-1]),
                                    initializer = tf.keras.initializers.constant(0.001),
                                    trainable = True,
                                    constraint = lambda x: tf.clip_by_value(x, 1e-15, np.inf))
        
        self.alpha = self.add_weight(name = 'alpha', 
                                     shape = (input_shape.as_list()[-1]),
                                     initializer = tf.keras.initializers.constant(2.0),
                                     trainable = True,
                                     constraint = NonNeg())

        self.epsilon = self.add_weight(name = 'epsilon', 
                                     shape = (input_shape.as_list()[-1]),
                                     initializer = tf.keras.initializers.constant(0.5),
                                     trainable = True,
                                     constraint = NonNeg())
        
        self.gamma = self.add_weight(name = 'gamma', 
                                     shape = (self.filter_shape[0], self.filter_shape[1], input_shape.as_list()[-1], input_shape.as_list()[-1]),
                                     initializer = tf.keras.initializers.Ones,
                                     trainable = True,
                                     constraint = NonNeg())
        
        
        super(GDN, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        norm_conv2 = tf.nn.convolution(tf.abs(x)**self.alpha,
                                      self.gamma,
                                      strides = (1, 1),
                                      padding = "SAME",
                                      data_format = "NHWC")

        norm_conv = self.beta + norm_conv2
        norm_conv = norm_conv**self.epsilon
        return x / norm_conv
        
    def compute_output_shape(self, input_shape):
        return (input_shape, self.output_dim)

# %%
def sacar_open_5_valores_normalizado_y_con_numero_de_valores_SIN_RETORNO_LOG ():
    # Para leer datos lo mejor es usar la toolbox pandas
    # Los datos se han sacado de:
    # https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/version/3
    
    
    dd_amzn = pd.read_csv("amzn.us.txt", delimiter=",")
    dd_msft = pd.read_csv("msft.us.txt", delimiter=",")
    dd_fb = pd.read_csv("fb.us.txt", delimiter=",")
    dd_aapl = pd.read_csv("aapl.us.txt", delimiter=",")
    dd_googl = pd.read_csv("googl.us.txt", delimiter=",")
    
    
    amzn_op = dd_amzn['Open'].values
    msft_op = dd_msft['Open'].values
    fb_op = dd_fb['Open'].values
    aapl_op = dd_aapl['Open'].values
    googl_op = dd_googl['Open'].values
    
    print(amzn_op.shape)
    print(msft_op.shape)
    print(fb_op.shape)
    print(aapl_op.shape)
    print(googl_op.shape)
    
    # Como no coinciden en el tiempo los 5 valores me cojo solo los que coinciden
    # Primero me los ordeno teniendo en cuenta la fecha
    aa = dd_amzn['Date'].values #
    amzn_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        amzn_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #


    aa = dd_msft['Date'].values #
    msft_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        msft_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_fb['Date'].values #
    fb_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        fb_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_aapl['Date'].values #
    aapl_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        aapl_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_googl['Date'].values #
    googl_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        googl_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #
    
    
    import matplotlib.pyplot as plt
    # %matplotlib inline
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 10)) 
    
    
    # Los ploteo y veo que hay un tramo en el coinciden las fechas
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax1.plot(amzn_indice,amzn_op, label='amzn_indice,amzn_op')
    ax1.plot(msft_indice,msft_op, label='msft_indice,msft_opp')
    ax1.plot(fb_indice,fb_op, label='fb_indice,fb_op')
    ax1.plot(aapl_indice,aapl_op, label='aapl_indice,aapl_op')
    ax1.plot(googl_indice,googl_op, label='googl_indice,googl_op')
    ax1.legend()
    
    # Me quedo solo las fechas que coinciden
    indices = set(amzn_indice) & set(msft_indice) & set(fb_indice) & set(aapl_indice) & set(aapl_indice)

    ii = np.in1d(amzn_indice,list(indices))
    data_amzn = amzn_op[ii]
    ii = np.in1d(msft_indice,list(indices))
    data_msft = msft_op[ii]
    ii = np.in1d(fb_indice,list(indices))
    data_fb = fb_op[ii]
    ii = np.in1d(aapl_indice,list(indices))
    data_aapl = aapl_op[ii]
    ii = np.in1d(googl_indice,list(indices))
    data_googl = googl_op[ii]



    # Los ploteo y ahora síí coinciden en todo el tramo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax2.plot(data_amzn, label='data_amzn')
    ax2.plot(data_msft, label='data_msft')
    ax2.plot(data_fb, label='data_fb')
    ax2.plot(data_aapl, label='data_aapl')
    ax2.plot(data_googl, label='data_googl')
    ax2.legend()
    
    # Los coloco todos juntos en un dataset
    DAT = np.zeros((data_googl.shape[0],5))
    DAT[:,1] = data_amzn
    DAT[:,0] = data_msft
    DAT[:,2] = data_fb
    DAT[:,3] = data_aapl
    DAT[:,4] = data_googl

    # Los ploteo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax3.plot(DAT[:,0], label='data_msft')
    ax3.plot(DAT[:,1], label='data_amzn')
    ax3.plot(DAT[:,2], label='data_fb')
    ax3.plot(DAT[:,3], label='data_aapl')
    ax3.plot(DAT[:,4], label='data_googl')
    ax3.legend()
    
    #normalizo de 0 a 1. Esto no cubre la ############### pero me deja todo normalizado
    # se podria usar a lo menos DAT = StandardScaler().fit_transform(DAT). 
    # pero se a usado para otro tipo de casos y me da valores mayoires de 1 y menores de -1
    DAT[:,0] = DAT[:,0]/DAT[:,0].max()
    DAT[:,1] = DAT[:,1]/DAT[:,1].max()
    DAT[:,2] = DAT[:,2]/DAT[:,2].max()
    DAT[:,3] = DAT[:,3]/DAT[:,3].max()
    DAT[:,4] = DAT[:,4]/DAT[:,4].max()
    
    # Los ploteo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax4.plot(DAT[:,0], label='data_msft')
    ax4.plot(DAT[:,1], label='data_amzn')
    ax4.plot(DAT[:,2], label='data_fb')
    ax4.plot(DAT[:,3], label='data_aapl')
    ax4.plot(DAT[:,4], label='data_googl')
    ax4.legend()

    
    return DAT

# %%
def sacar_open_5_valores_SIN_normalizado_y_con_numero_de_valores_CON_RETORNO_LOG ():
    # Para leer datos lo mejor es usar la toolbox pandas
    # Los datos se han sacado de:
    # https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/version/3
    
    
    dd_amzn = pd.read_csv("amzn.us.txt", delimiter=",")
    dd_msft = pd.read_csv("msft.us.txt", delimiter=",")
    dd_fb = pd.read_csv("fb.us.txt", delimiter=",")
    dd_aapl = pd.read_csv("aapl.us.txt", delimiter=",")
    dd_googl = pd.read_csv("googl.us.txt", delimiter=",")
    
    
    amzn_op = dd_amzn['Open'].values
    msft_op = dd_msft['Open'].values
    fb_op = dd_fb['Open'].values
    aapl_op = dd_aapl['Open'].values
    googl_op = dd_googl['Open'].values
    
    print(amzn_op.shape)
    print(msft_op.shape)
    print(fb_op.shape)
    print(aapl_op.shape)
    print(googl_op.shape)
    
    # Como no coinciden en el tiempo los 5 valores me cojo solo los que coinciden
    # Primero me los ordeno teniendo en cuenta la fecha
    aa = dd_amzn['Date'].values #
    amzn_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        amzn_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #


    aa = dd_msft['Date'].values #
    msft_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        msft_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_fb['Date'].values #
    fb_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        fb_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_aapl['Date'].values #
    aapl_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        aapl_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #

    aa = dd_googl['Date'].values #
    googl_indice = np.zeros(aa.shape) #
    for n in range(0, aa.shape[0]):
        cc = aa[n]
        qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
        qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
        qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

        googl_indice[n] = (qq1-2000)*365 + qq2*30 + qq3 #
    
    
    import matplotlib.pyplot as plt
    # %matplotlib inline
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 10)) 
    
    
    # Los ploteo y veo que hay un tramo en el coinciden las fechas
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax1.plot(amzn_indice,amzn_op, label='amzn_indice,amzn_op')
    ax1.plot(msft_indice,msft_op, label='msft_indice,msft_opp')
    ax1.plot(fb_indice,fb_op, label='fb_indice,fb_op')
    ax1.plot(aapl_indice,aapl_op, label='aapl_indice,aapl_op')
    ax1.plot(googl_indice,googl_op, label='googl_indice,googl_op')
    ax1.legend()
    
    # Me quedo solo las fechas que coinciden
    indices = set(amzn_indice) & set(msft_indice) & set(fb_indice) & set(aapl_indice) & set(aapl_indice)

    ii = np.in1d(amzn_indice,list(indices))
    data_amzn = amzn_op[ii]
    ii = np.in1d(msft_indice,list(indices))
    data_msft = msft_op[ii]
    ii = np.in1d(fb_indice,list(indices))
    data_fb = fb_op[ii]
    ii = np.in1d(aapl_indice,list(indices))
    data_aapl = aapl_op[ii]
    ii = np.in1d(googl_indice,list(indices))
    data_googl = googl_op[ii]



    # Los ploteo y ahora síí coinciden en todo el tramo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax2.plot(data_amzn, label='data_amzn')
    ax2.plot(data_msft, label='data_msft')
    ax2.plot(data_fb, label='data_fb')
    ax2.plot(data_aapl, label='data_aapl')
    ax2.plot(data_googl, label='data_googl')
    ax2.legend()
    
    # Los coloco todos juntos en un dataset
    DAT = np.zeros((data_googl.shape[0],5))
    DAT[:,1] = data_amzn
    DAT[:,0] = data_msft
    DAT[:,2] = data_fb
    DAT[:,3] = data_aapl
    DAT[:,4] = data_googl

    # Los ploteo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax3.plot(DAT[:,0], label='data_msft')
    ax3.plot(DAT[:,1], label='data_amzn')
    ax3.plot(DAT[:,2], label='data_fb')
    ax3.plot(DAT[:,3], label='data_aapl')
    ax3.plot(DAT[:,4], label='data_googl')
    ax3.legend()
    
  
    #Aplico el retorno logaritmico
    DAT_1 = np.diff(np.log(DAT),axis=0)
    #DAT_1[:,0] = np.diff(np.log(DAT[:,0]),axis=0)
    #DAT_1[:,1] = np.diff(np.log(DAT[:,1]),axis=0)
    #DAT_1[:,2] = np.diff(np.log(DAT[:,2]),axis=0)
    #DAT_1[:,3] = np.diff(np.log(DAT[:,3]),axis=0)
    #DAT_1[:,4] = np.diff(np.log(DAT[:,4]),axis=0)
    
    # Los ploteo
    #import matplotlib.pyplot as plt
    #%matplotlib inline
    #plt.figure()
    ax4.plot(DAT_1[:,0], label='data_msft')
    ax4.plot(DAT_1[:,1], label='data_amzn')
    ax4.plot(DAT_1[:,2], label='data_fb')
    ax4.plot(DAT_1[:,3], label='data_aapl')
    ax4.plot(DAT_1[:,4], label='data_googl')
    ax4.legend()
    
    return DAT_1

# %%
def Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG,DAT_1):
    # Reordeno el dataset para hacer bloques de LAG dias
    #LAG = 11
    DAT_TS = np.zeros((DAT_1.shape[0]-LAG,LAG,DAT_1.shape[1]))

    for ii in range(0,DAT_1.shape[0]-LAG):
        #print(DAT_TS.shape)
        #print(DAT_1.shape)
        DAT_TS[ii,:,:] = DAT_1[ii:ii+LAG,:]
    # Tengo (#muestras,#longitud,#variables)

    #Separaro todo el dataset en los datos de apertura de 10 días anteriores para estimar el valor del día
    #actual
    #Ntr = np.floor(DAT_TS.shape[0]/2)
    Ntr = np.floor(DAT_TS.shape[0])
    data_x = DAT_TS[range(0,np.int(Ntr)),0:LAG-1,:]

    Y_target = 0
    data_y = DAT_TS[range(0,np.int(Ntr)),LAG-1,Y_target]

    #print(data_x[700])
    #print(data_y[700])


    #hago el split de train y test
    from sklearn.model_selection import train_test_split
    x_train, x_test, t_train, t_test = train_test_split(data_x, data_y, test_size=0.33, random_state=12)

    return x_train, x_test, t_train, t_test

# %%
def reshape_para_trabajar_conv2D (x_train,x_test):
    # Modifico las dimensiones para poder usar convoluciones 2D
    # Para eso incluyo una dimension de canales al final
    x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],1)
    x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],1)
    return x_train, x_test

# %%
# Evaluamos el modelo segun los datos mas generales para evaluarlo

def graficas_y_valores_estandar_evaluacion_modelo(x_train, t_train,x_test, t_test, model, hist):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    #Train
    score = model.evaluate(x_train, t_train)
    print('SCORE DE TRAIN:')
    print(score)

    #Test
    print('SCORE DE TEST:')
    score_1 = model.evaluate(x_test, t_test)
    print(score_1)

    n_epochs = len(hist.history['loss'])
    hd = hist.history
    epochs = range(1, n_epochs+1)
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(epochs, hd['accuracy'], "r", label="train")
    plt.plot(epochs, hd['val_accuracy'], "b", label="valid")
    plt.grid(True)
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.title("Accuracy")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, hd['loss'], "r", label="train")
    plt.plot(epochs, hd['val_loss'], "b", label="valid")
    plt.grid(True)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.title("Loss")
    plt.legend()
    plt.show()
    return score, score_1

# %%
#Cree esta funcion segun lo que Valero son ensenaba en clase
def ESTUDIO_GRAFICO_DE_RESULTADOS_PARA_EVALUAR(x_train, x_test, t_train, t_test, model):
    
    #ESTUDIO GRAFICO DE RESULTADOS PARA EVALUAR
    # Evaluamos el modelo en train
    score = model.evaluate(x_train, t_train, verbose=0)
    print(f'Evaluamos el modelo en train_score: {score}')

    # Predecimos con los datos de train
    y_hat = model.predict(x_train)
    print(f'Predecimos con los datos de train: {np.mean(abs(y_hat[:,0]-t_train))}')
    print(f'Predecimos con los datos de train_cantidad/dimensiones de datos:{y_hat.shape}')
    print(f' La media de error en la prediccion en entrenamiento es: {np.mean(np.abs(t_train))}')

    # Predecimos con los datos de test
    y_hat_test = model.predict(x_test)
    print(f' El  error de la predicion usando datos de test es de : {np.mean(abs(y_hat_test[:,0]-t_test))}')
    print(f' La media de error en la prediccion en test es: {np.mean(np.abs(t_test))}')

    import matplotlib.pyplot as plt
    # %matplotlib inline
    fig, ((ax1, ax2),(ax3, ax4),(ax5,ax6)) = plt.subplots(3, 2, figsize=(20, 10)) 
    # Mostramos las predicciones de entrenamiento
    print(f'Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:')

    #plt.figure()
    ax1.plot(y_hat[:,0], label='y_hat[:,0] datos')    
    ax1.plot(t_train, label='t_train predicciones')
    ax1.grid(True)
    #ax1.xlabel("valores")
    #ax1.ylabel("nuero de dato ordinalmente")
    ax1.legend()

    #plt.figure()
    ax2.plot(t_train,y_hat[:,0],'.', label='t_train VSy_hat[:,0],')
    ax2.grid(True)
    #ax2.xlabel("t_train")
    #ax2.ylabel("y_hat[:,0],")
    ax2.legend()

    # Mostramos las predicciones de test
    ax3.plot(y_hat_test[:,0], label='y_hat_test[:,0] datos')
    ax3.plot(t_test, label=' t_testpredicciones')
    ax3.grid(True)
    #ax3.xlabel("valores")
    #ax3.ylabel("nuero de dato ordinalmente")
    ax3.legend()

    ax4.plot(t_test,y_hat_test[:,0],'.', label='t_test VS y_hat_test[:,0]')
    ax4.grid(True)
    #ax4.xlabel("t_test")
    #ax4.ylabel("y_hat_test[:,0]")
    ax4.legend()

    
    ax5.plot(model.weights[0].numpy().reshape(-1),'o-',label="Pesos neurona primera capa")
    ax5.grid(True)
    #ax5.xlabel("numero de la neurona ordinalmente")
    #ax5.ylabel("peso de la neurona")
    #ax5.title("Pesos neurona primera capa")
    ax5.legend()
    
    return

# %%
def activo_caso_1(x_train, x_test, t_train, t_test):
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout,MaxPooling2D 
    from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, GlobalAveragePooling1D,GlobalMaxPooling1D
    from tensorflow.keras import regularizers
    import tensorflow as tf
    from tensorflow import keras
    import numpy as np
    import matplotlib.pyplot as plt
    from time import time
    import shutil

    # !pip install -q -U keras-tuner
    import keras_tuner as kt

    #####################################METER GDN
    model = Sequential()
    model.add(GDN(input_shape = x_train.shape[1:]))
    model.add(Conv2D(10, 3, input_shape=(10,5,), padding='same'))
    #model.add(Conv2D(10, 3, input_shape=x_train.shape[1:], padding='same'))    
    model.add(Activation("relu"))
    model.add(Dropout(0.3))
    model.add(MaxPooling2D(2))
    model.add(Reshape((5*2,10))) #https://github.com/keras-team/keras/issues/4172
    model.add(LSTM(5,return_sequences=True))
    #model.add(Bidirectional(GRU(20), input_shape=(10,1), merge_mode="ave"))
    model.add(GRU(5))
    model.add(Flatten())
    model.add(Dense(1))


    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mean_squared_error', metrics=['accuracy'])
    #model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mae', metrics=['accuracy'])
    model.summary()

    # Vamos a usar el callback de earlystopping y ReduceLROnPlateau
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
    #early_stopping = EarlyStopping(monitor='val_loss', patience=12, min_delta=0.1)
    early_stopping = EarlyStopping(monitor='loss', patience=12, min_delta=0.1)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=5, min_lr=0.1)


    # Entrenamos el modelo, nos guardamos la evolución en 'history' 
    # Esto es equivalente a usar callbacks para history
    hist = model.fit(x_train, t_train, batch_size=32, epochs=100, verbose=1, validation_split = 0.1) # antes epochs=1000
    
    #Parametros para evaluar
    score_train, score_test = graficas_y_valores_estandar_evaluacion_modelo(x_train, t_train,x_test, t_test, model, hist)
    ESTUDIO_GRAFICO_DE_RESULTADOS_PARA_EVALUAR(x_train, x_test, t_train, t_test, model)
    
    return model, hist

# %%
def activo_caso_2(x_train, x_test, t_train, t_test):
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout,MaxPooling2D 
    from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, GlobalAveragePooling1D,GlobalMaxPooling1D
    from tensorflow.keras import regularizers
    import tensorflow as tf
    from tensorflow import keras
    import numpy as np
    import matplotlib.pyplot as plt
    from time import time
    import shutil

    # !pip install -q -U keras-tuner
    import keras_tuner as kt

    

    model = Sequential()
    model.add(GDN(input_shape = x_train.shape[1:]))
    model.add(Conv2D(10,3,padding='same'))
    #model.add(Conv2D(10,3, input_shape=(x_train.shape[1:]),padding='same'))
    model.add(Reshape((10*5,10)))
    model.add(GRU(5,return_sequences=True))
    model.add(LSTM(5))
    model.add(Flatten())
    model.add(Dense(1))



    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mean_squared_error', metrics=['accuracy'])
    #model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mae', metrics=['accuracy'])
    model.summary()

    # Vamos a usar el callback de earlystopping y ReduceLROnPlateau
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
    #early_stopping = EarlyStopping(monitor='val_loss', patience=12, min_delta=0.1)
    early_stopping = EarlyStopping(monitor='loss', patience=12, min_delta=0.1)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=5, min_lr=0.1)


    # Entrenamos el modelo, nos guardamos la evolución en 'history' 
    # Esto es equivalente a usar callbacks para history
    hist = model.fit(x_train, t_train, batch_size=32, epochs=100, verbose=1, validation_split = 0.1) # antes epochs=1000
    
    #Parametros para evaluar
    score_train, score_test = graficas_y_valores_estandar_evaluacion_modelo(x_train, t_train,x_test, t_test, model, hist)
    ESTUDIO_GRAFICO_DE_RESULTADOS_PARA_EVALUAR(x_train, x_test, t_train, t_test, model)
    
    return model, hist

# %%
def activo_caso_3(x_train, x_test, t_train, t_test):
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout,MaxPooling2D 
    from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, GlobalAveragePooling1D,GlobalMaxPooling1D
    from tensorflow.keras import regularizers
    import tensorflow as tf
    from tensorflow import keras
    import numpy as np
    import matplotlib.pyplot as plt
    from time import time
    import shutil

    # !pip install -q -U keras-tuner
    import keras_tuner as kt

    

    # Otra posibilidad 2 convolucionales 2D y 2 densas
    

    model = Sequential()
    model.add(GDN(input_shape = x_train.shape[1:]))
    model.add(Conv2D(5, 3, padding='same'))
    #model.add(Conv2D(5, 3, input_shape=x_train.shape[1:], padding='same'))
    model.add(Conv2D(5, 3, padding='valid'))
    model.add(Flatten())
    model.add(Dense(3))
    model.add(Dense(1))



    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mean_squared_error', metrics=['accuracy'])
    #model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mae', metrics=['accuracy'])
    model.summary()

    # Vamos a usar el callback de earlystopping y ReduceLROnPlateau
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
    #early_stopping = EarlyStopping(monitor='val_loss', patience=12, min_delta=0.1)
    early_stopping = EarlyStopping(monitor='loss', patience=12, min_delta=0.1)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=5, min_lr=0.1)


    # Entrenamos el modelo, nos guardamos la evolución en 'history' 
    # Esto es equivalente a usar callbacks para history
    hist = model.fit(x_train, t_train, batch_size=32, epochs=100, verbose=1, validation_split = 0.1) # antes epochs=1000
    
    #Parametros para evaluar
    score_train, score_test = graficas_y_valores_estandar_evaluacion_modelo(x_train, t_train,x_test, t_test, model, hist)
    ESTUDIO_GRAFICO_DE_RESULTADOS_PARA_EVALUAR(x_train, x_test, t_train, t_test, model)
    
    return model, hist

# %%
def activo_caso_4(x_train, x_test, t_train, t_test):
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout,MaxPooling2D 
    from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, GlobalAveragePooling1D,GlobalMaxPooling1D
    from tensorflow.keras import regularizers
    import tensorflow as tf
    from tensorflow import keras
    import numpy as np
    import matplotlib.pyplot as plt
    from time import time
    import shutil

    # !pip install -q -U keras-tuner
    import keras_tuner as kt

    
    # modelo con 3 capas de Conv2D y con mas cositinas y una densa al final
    
    #######################METER GDU
    model = Sequential()
    #Vamos añadiendo capas
    #model.add(Conv2D(8, kernel_size=3, activation='relu', input_shape=x_train.shape[1:], padding='same'))
    model.add(GDN(input_shape = x_train.shape[1:]))
    model.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
    #                activity_regularizer=regularizers.l1(0.2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    #model.add(MaxPooling2D(2))
    model.add(Conv2D(3, kernel_size=5, activation='relu', padding='same'))
    #                activity_regularizer=regularizers.l1(0.2)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPooling2D())
    model.add(Conv2D(3, kernel_size=3, activation='relu', padding='same'))
    #                activity_regularizer=regularizers.l1(0.2)))
    model.add(MaxPooling2D(2))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(1))




    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mean_squared_error', metrics=['accuracy'])
    #model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss = 'mae', metrics=['accuracy'])
    model.summary()

    # Vamos a usar el callback de earlystopping y ReduceLROnPlateau
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
    #early_stopping = EarlyStopping(monitor='val_loss', patience=12, min_delta=0.1)
    early_stopping = EarlyStopping(monitor='loss', patience=12, min_delta=0.1)

    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=5, min_lr=0.1)


    # Entrenamos el modelo, nos guardamos la evolución en 'history' 
    # Esto es equivalente a usar callbacks para history
    hist = model.fit(x_train, t_train, batch_size=32, epochs=100, verbose=1, validation_split = 0.1) # antes epochs=1000
    
    #Parametros para evaluar
    score_train, score_test = graficas_y_valores_estandar_evaluacion_modelo(x_train, t_train,x_test, t_test, model, hist)
    ESTUDIO_GRAFICO_DE_RESULTADOS_PARA_EVALUAR(x_train, x_test, t_train, t_test, model)
    
    return model, hist

# %%
DAT = sacar_open_5_valores_normalizado_y_con_numero_de_valores_SIN_RETORNO_LOG ()
x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
x_train, x_test = reshape_para_trabajar_conv2D (x_train,x_test)
model, hist = activo_caso_1(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_1_GDN(input_shape_Conv2D(10, 3_MaxPooling2D(2_LSTM(5_GRU(5_Dense(1_NORMALIZADO_SIN_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# (5153,)
# (7983,)
# (1381,)
# (8364,)
# (3333,)
# <ipython-input-8-79e198143002>:16: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data_x = DAT_TS[range(0,np.int(Ntr)),0:LAG-1,:]
# <ipython-input-8-79e198143002>:19: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data_y = DAT_TS[range(0,np.int(Ntr)),LAG-1,Y_target]
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 KB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.9 MB/s eta 0:00:00
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn (GDN)                   (None, 10, 5, 1)          12
#
#  conv2d (Conv2D)             (None, 10, 5, 10)         100
#
#  activation (Activation)     (None, 10, 5, 10)         0
#
#  dropout (Dropout)           (None, 10, 5, 10)         0
#
#  max_pooling2d (MaxPooling2D  (None, 5, 2, 10)         0
#  )
#
#  reshape (Reshape)           (None, 10, 10)            0
#
#  lstm (LSTM)                 (None, 10, 5)             320
#
#  gru (GRU)                   (None, 5)                 180
#
#  flatten (Flatten)           (None, 5)                 0
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 618
# Trainable params: 618
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 16s 43ms/step - loss: 0.0617 - accuracy: 0.0012 - val_loss: 0.0300 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0289 - accuracy: 0.0000e+00 - val_loss: 0.0256 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0133 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 0.0012 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.0012 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.0012 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.0012 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 26/26 [==============================] - 0s 8ms/step - loss: 9.7957e-04 - accuracy: 0.0012 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 26/26 [==============================] - 0s 8ms/step - loss: 9.9928e-04 - accuracy: 0.0012 - val_loss: 0.0057 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.0012 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 26/26 [==============================] - 0s 9ms/step - loss: 8.9653e-04 - accuracy: 0.0012 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 0.0012 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 26/26 [==============================] - 0s 8ms/step - loss: 8.4326e-04 - accuracy: 0.0012 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 26/26 [==============================] - 0s 9ms/step - loss: 8.6218e-04 - accuracy: 0.0012 - val_loss: 0.0058 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 26/26 [==============================] - 0s 8ms/step - loss: 9.9372e-04 - accuracy: 0.0012 - val_loss: 0.0058 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 26/26 [==============================] - 0s 8ms/step - loss: 9.8555e-04 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 0.0092 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 26/26 [==============================] - 0s 9ms/step - loss: 8.4996e-04 - accuracy: 0.0012 - val_loss: 0.0054 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 26/26 [==============================] - 0s 9ms/step - loss: 9.7967e-04 - accuracy: 0.0012 - val_loss: 0.0042 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 26/26 [==============================] - 0s 9ms/step - loss: 8.5010e-04 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 26/26 [==============================] - 0s 8ms/step - loss: 7.9979e-04 - accuracy: 0.0012 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 26/26 [==============================] - 0s 11ms/step - loss: 8.5695e-04 - accuracy: 0.0012 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 26/26 [==============================] - 0s 11ms/step - loss: 9.9372e-04 - accuracy: 0.0012 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 26/26 [==============================] - 0s 11ms/step - loss: 8.2613e-04 - accuracy: 0.0012 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 26/26 [==============================] - 0s 11ms/step - loss: 8.4240e-04 - accuracy: 0.0012 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 26/26 [==============================] - 0s 11ms/step - loss: 8.0651e-04 - accuracy: 0.0012 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 26/26 [==============================] - 0s 11ms/step - loss: 9.9417e-04 - accuracy: 0.0012 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 26/26 [==============================] - 0s 12ms/step - loss: 9.7197e-04 - accuracy: 0.0012 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 26/26 [==============================] - 0s 11ms/step - loss: 8.9638e-04 - accuracy: 0.0012 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 26/26 [==============================] - 0s 8ms/step - loss: 7.7943e-04 - accuracy: 0.0012 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 26/26 [==============================] - 0s 9ms/step - loss: 8.3789e-04 - accuracy: 0.0012 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 26/26 [==============================] - 0s 8ms/step - loss: 7.1983e-04 - accuracy: 0.0012 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 26/26 [==============================] - 0s 8ms/step - loss: 8
- val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.8618e-04 - accuracy: 0.0012 - val_loss: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 26/26 [==============================] - 0s 9ms/step - loss: 4.9817e-04 - accuracy: 0.0012 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 26/26 [==============================] - 0s 9ms/step - loss: 4.7031e-04 - accuracy: 0.0012 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.7169e-04 - accuracy: 0.0012 - val_loss: 0.0042 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 26/26 [==============================] - 0s 9ms/step - loss: 4.3989e-04 - accuracy: 0.0012 - val_loss: 0.0042 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.9945e-04 - accuracy: 0.0012 - val_loss: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.9579e-04 - accuracy: 0.0012 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3230e-04 - accuracy: 0.0012 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.6979e-04 - accuracy: 0.0012 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.7760e-04 - accuracy: 0.0012 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.8462e-04 - accuracy: 0.0012 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.0011
# SCORE DE TRAIN:
# [0.003146108705550432, 0.0010905124945566058]
# SCORE DE TEST:
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.0000e+00
# [0.003136205719783902, 0.0]
# Evaluamos el modelo en train_score: [0.003146108705550432, 0.0010905124945566058]
# 29/29 [==============================] - 1s 3ms/step
# Predecimos con los datos de train: 0.041884399297297516
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.5219936066660071
# 15/15 [==============================] - 0s 3ms/step
#  El  error de la predicion usando datos de test es de : 0.041716927782097395
#  La media de error en la prediccion en test es: 0.5205517800275568
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 1s 14ms/step - loss: 0.0031 - accuracy: 0.0011
# 29/29 [==============================] - 0s 9ms/step
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.0000e+00
# 15/15 [==============================] - 0s 7ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_normalizado_y_con_numero_de_valores_SIN_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_2(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_2_GDN(input_shape_Conv2D(10,3_GRU(5_LSTM(5_Dense(1_NORMALIZADO_SIN_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn_1 (GDN)                 (None, 10, 5, 1)          12
#
#  conv2d_1 (Conv2D)           (None, 10, 5, 10)         100
#
#  reshape_1 (Reshape)         (None, 50, 10)            0
#
#  gru_1 (GRU)                 (None, 50, 5)             255
#
#  lstm_1 (LSTM)               (None, 5)                 220
#
#  flatten_1 (Flatten)         (None, 5)                 0
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 593
# Trainable params: 593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 10s 73ms/step - loss: 0.0397 - accuracy: 0.0000e+00 - val_loss: 0.0282 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0243 - accuracy: 0.0000e+00 - val_loss: 0.0150 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0055 - accuracy: 0.0012 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 0.0012 - val_loss: 9.8632e-04 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.0012 - val_loss: 9.4101e-04 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.0012 - val_loss: 7.2680e-04 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 26/26 [==============================] - 1s 20ms/step - loss: 9.5896e-04 - accuracy: 0.0012 - val_loss: 8.9489e-04 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 7.2237e-04 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 26/26 [==============================] - 0s 17ms/step - loss: 8.5890e-04 - accuracy: 0.0012 - val_loss: 8.4868e-04 - val_accuracy: 0.0000e+00
# Epoch 11/100
#
# 29/29 [==============================] - 0s 5ms/step - loss: 7.4114e-05 - accuracy: 0.0011
# 29/29 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 5ms/step - loss: 7.6767e-05 - accuracy: 0.0000e+00
# 15/15 [==============================] - 0s 3ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_normalizado_y_con_numero_de_valores_SIN_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_3(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_3_GDN(input_shape_Conv2D(5, 3_Conv2D(5, 3_Dense(3_Dense(1__NORMALIZADO_SIN_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn_2 (GDN)                 (None, 10, 5, 1)          12
#
#  conv2d_2 (Conv2D)           (None, 10, 5, 5)          50
#
#  conv2d_3 (Conv2D)           (None, 8, 3, 5)           230
#
#  flatten_2 (Flatten)         (None, 120)               0
#
#  dense_2 (Dense)             (None, 3)                 363
#
#  dense_3 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 659
# Trainable params: 659
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 5s 25ms/step - loss: 0.0842 - accuracy: 0.0012 - val_loss: 0.0253 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0123 - accuracy: 0.0012 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0050 - accuracy: 0.0012 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.0012 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 0.0012 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 0.0012 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 0.0012 - val_loss: 9.3186e-04 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 0.0012 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 0.0012 - val_loss: 7.7828e-04 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 9.7039e-04 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 26/26 [==============================] - 0s 10ms/step - loss: 9.6719e-04 - accuracy: 0.0012 - val_loss: 8.5498e-04 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 0.0012 - val_loss: 5.6772e-04 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 26/26 [==============================] - 0s 9ms/step - loss: 7.8835e-04 - accuracy: 0.0012 - val_loss: 7.2060e-04 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 26/26 [==============================] - 0s 12ms/step - loss: 7.5011e-04 - accuracy: 0.0012 - val_loss: 4.0043e-04 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 26/26 [==============================] - 0s 10ms/step - loss: 5.1374e-04 - accuracy: 0.0012 - val_loss: 3.1330e-04 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 26/26 [==============================] - 0s 13ms/step - loss: 4.8989e-04 - accuracy: 0.0012 - val_loss: 3.3921e-04 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 26/26 [==============================] - 0s 11ms/step - loss: 4.3327e-04 - accuracy: 0.0012 - val_loss: 3.6627e-04 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 26/26 [==============================] - 0s 12ms/step - loss: 3.7160e-04 - accuracy: 0.0012 - val_loss: 2.7447e-04 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.9465e-04 - accuracy: 0.0012 - val_loss: 1.7681e-04 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.7070e-04 - accuracy: 0.0012 - val_loss: 1.5124e-04 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 26/26 [==============================] - 0s 13ms/step - loss: 2.9050e-04 - accuracy: 0.0012 - val_loss: 1.6219e-04 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.7969e-04 - accuracy: 0.0012 - val_loss: 2.2850e-04 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 26/26 [==============================] - 0s 9ms/step - loss: 2.4430e-04 - accuracy: 0.0012 - val_loss: 2.0041e-04 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.2813e-04 - accuracy: 0.0012 - val_loss: 3.2851e-04 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.5116e-04 - accuracy: 0.0012 - val_loss: 2.1458e-04 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.5419e-04 - accuracy: 0.0012 - val_loss: 2.0519e-04 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 26/26 [==============================] - 0s 9ms/step - loss: 2.2581e-04 - accuracy: 0.0012 - val_loss: 1.3500e-04 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.5219936066660071
# 15/15 [==============================] - 0s 2ms/step
#  El  error de la predicion usando datos de test es de : 0.011953914239633174
#  La media de error en la prediccion en test es: 0.5205517800275568
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9944e-04 - accuracy: 0.0011
# 29/29 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 3ms/step - loss: 2.1248e-04 - accuracy: 0.0000e+00
# 15/15 [==============================] - 0s 2ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_normalizado_y_con_numero_de_valores_SIN_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_4(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_4_GDN(input_shape_Conv2D(8_Conv2D(3_MaxPooling2D(_Conv2D(3_MaxPooling2D(2_Dense(1__NORMALIZADO_SIN_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn_3 (GDN)                 (None, 10, 5, 1)          12
#
#  conv2d_4 (Conv2D)           (None, 10, 5, 8)          80
#
#  batch_normalization (BatchN  (None, 10, 5, 8)         32
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 10, 5, 8)          0
#
#  conv2d_5 (Conv2D)           (None, 10, 5, 3)          603
#
#  batch_normalization_1 (Batc  (None, 10, 5, 3)         12
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 10, 5, 3)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 2, 3)          0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 5, 2, 3)           84
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 1, 3)          0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 2, 1, 3)          12
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 2, 1, 3)           0
#
#  flatten_3 (Flatten)         (None, 6)                 0
#
#  dense_4 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 842
# Trainable params: 814
# Non-trainable params: 28
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 7s 36ms/step - loss: 0.5477 - accuracy: 0.0012 - val_loss: 0.1414 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1011 - accuracy: 0.0000e+00 - val_loss: 0.0958 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0573 - accuracy: 0.0012 - val_loss: 0.0716 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0462 - accuracy: 0.0000e+00 - val_loss: 0.0433 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0383 - accuracy: 0.0000e+00 - val_loss: 0.0351 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0356 - accuracy: 0.0000e+00 - val_loss: 0.0549 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0342 - accuracy: 0.0012 - val_loss: 0.0690 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0317 - accuracy: 0.0000e+00 - val_loss: 0.0705 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0316 - accuracy: 0.0012 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0315 - accuracy: 0.0012 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0287 - accuracy: 0.0012 - val_loss: 0.0826 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0283 - accuracy: 0.0000e+00 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0275 - accuracy: 0.0000e+00 - val_loss: 0.0280 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0220 - accuracy: 0.0012 - val_loss: 0.0300 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0222 - accuracy: 0.0012 - val_loss: 0.0270 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0215 - accuracy: 0.0012 - val_loss: 0.0191 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0173 - accuracy: 0.0012 - val_loss: 0.0182 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0153 - accuracy: 0.0012 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0146 - accuracy: 0.0012 - val_loss: 0.0151 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0119 - accuracy: 0.0012 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 0.0000e+00
# [0.0035996611695736647, 0.0]
# Evaluamos el modelo en train_score: [0.003634142456576228, 0.0010905124945566058]
# 29/29 [==============================] - 0s 4ms/step
# Predecimos con los datos de train: 0.04483039077556943
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.5219936066660071
# 15/15 [==============================] - 0s 2ms/step
#  El  error de la predicion usando datos de test es de : 0.044471892203549614
#  La media de error en la prediccion en test es: 0.5205517800275568
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.0011
# 29/29 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.0000e+00
# 15/15 [==============================] - 0s 2ms/step
# 17
# (17, 54)

# %%
DAT = sacar_open_5_valores_SIN_normalizado_y_con_numero_de_valores_CON_RETORNO_LOG ()
x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_1(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_1_GDN(input_shape_Conv2D(10, 3_MaxPooling2D(2_LSTM(5_GRU(5_Dense(1_CON_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# (5153,)
# (7983,)
# (1381,)
# (8364,)
# (3333,)
# <ipython-input-8-79e198143002>:16: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data_x = DAT_TS[range(0,np.int(Ntr)),0:LAG-1,:]
# <ipython-input-8-79e198143002>:19: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data_y = DAT_TS[range(0,np.int(Ntr)),LAG-1,Y_target]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn_4 (GDN)                 (None, 10, 5, 1)          12
#
#  conv2d_7 (Conv2D)           (None, 10, 5, 10)         100
#
#  activation_1 (Activation)   (None, 10, 5, 10)         0
#
#  dropout_4 (Dropout)         (None, 10, 5, 10)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 2, 10)         0
#  2D)
#
#  reshape_2 (Reshape)         (None, 10, 10)            0
#
#  lstm_2 (LSTM)               (None, 10, 5)             320
#
#  gru_2 (GRU)                 (None, 5)                 180
#
#  flatten_4 (Flatten)         (None, 5)                 0
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 618
# Trainable params: 618
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 11s 65ms/step - loss: 0.0026 - accuracy: 0.0121 - val_loss: 2.5132e-04 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 15ms/step - loss: 3.1327e-04 - accuracy: 0.0121 - val_loss: 1.4642e-04 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.2758e-04 - accuracy: 0.0121 - val_loss: 1.5034e-04 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 12ms/step - loss: 2.2888e-04 - accuracy: 0.0121 - val_loss: 1.4001e-04 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 26/26 [==============================] - 0s 15ms/step - loss: 2.2778e-04 - accuracy: 0.0121 - val_loss: 1.3877e-04 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 26/26 [==============================] - 0s 16ms/step - loss: 2.2502e-04 - accuracy: 0.0121 - val_loss: 1.5058e-04 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 26/26 [==============================] - 0s 13ms/step - loss: 2.2541e-04 - accuracy: 0.0121 - val_loss: 1.3981e-04 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 26/26 [==============================] - 0s 17ms/step - loss: 2.2434e-04 - accuracy: 0.0121 - val_loss: 1.6655e-04 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 26/26 [==============================] - 0s 18ms/step - loss: 2.3378e-04 - accuracy: 0.0121 - val_loss: 1.3805e-04 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 26/26 [==============================] - 0s 15ms/step - loss: 2.3193e-04 - accuracy: 0.0121 - val_loss: 1.4388e-04 - val_accuracy: 0.0000e+00
# Epoch 11/100
#
- val_accuracy: 0.0000e+00
# Epoch 93/100
# 26/26 [==============================] - 0s 9ms/step - loss: 2.2243e-04 - accuracy: 0.0121 - val_loss: 1.3966e-04 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.1923e-04 - accuracy: 0.0121 - val_loss: 1.4369e-04 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 26/26 [==============================] - 0s 9ms/step - loss: 2.2833e-04 - accuracy: 0.0121 - val_loss: 1.4755e-04 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.2587e-04 - accuracy: 0.0121 - val_loss: 1.5125e-04 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 26/26 [==============================] - 0s 9ms/step - loss: 2.1703e-04 - accuracy: 0.0121 - val_loss: 1.3604e-04 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.2504e-04 - accuracy: 0.0121 - val_loss: 1.5030e-04 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.2628e-04 - accuracy: 0.0121 - val_loss: 1.3730e-04 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.2296e-04 - accuracy: 0.0121 - val_loss: 1.4232e-04 - val_accuracy: 0.0000e+00
# 29/29 [==============================] - 0s 5ms/step - loss: 2.1814e-04 - accuracy: 0.0109
# SCORE DE TRAIN:
# [0.00021813523198943585, 0.010905125178396702]
# SCORE DE TEST:
# 15/15 [==============================] - 0s 7ms/step - loss: 1.8667e-04 - accuracy: 0.0066
# [0.00018666991672944278, 0.006637168116867542]
# Evaluamos el modelo en train_score: [0.00021813523198943585, 0.010905125178396702]
# 29/29 [==============================] - 1s 3ms/step
# Predecimos con los datos de train: 0.010208751771752797
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.009929878888422247
# 15/15 [==============================] - 0s 3ms/step
#  El  error de la predicion usando datos de test es de : 0.009516186227983371
#  La media de error en la prediccion en test es: 0.009271483187945665
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 0s 4ms/step - loss: 2.1814e-04 - accuracy: 0.0109
# 29/29 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 4ms/step - loss: 1.8667e-04 - accuracy: 0.0066
# 15/15 [==============================] - 0s 3ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_SIN_normalizado_y_con_numero_de_valores_CON_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_2(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_2_GDN(input_shape_Conv2D(10,3_GRU(5_LSTM(5_Dense(1_NORMALIZADO_CON_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gdn_5 (GDN)                 (None, 10, 5, 1)          12
#
#  conv2d_8 (Conv2D)           (None, 10, 5, 10)         100
#
#  reshape_3 (Reshape)         (None, 50, 10)            0
#
#  gru_3 (GRU)                 (None, 50, 5)             255
#
#  lstm_3 (LSTM)               (None, 5)                 220
#
#  flatten_5 (Flatten)         (None, 5)                 0
#
#  dense_6 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 593
# Trainable params: 593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 11s 71ms/step - loss: 0.0013 - accuracy: 0.0121 - val_loss: 2.6196e-04 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 26/26 [==============================] - 0s 15ms/step - loss: 2.5127e-04 - accuracy: 0.0121 - val_loss: 1.3633e-04 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 26/26 [==============================] - 0s 17ms/step - loss: 2.2249e-04 - accuracy: 0.0121 - val_loss: 1.3566e-04 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 26/26 [==============================] - 0s 17ms/step - loss: 2.2251e-04 - accuracy: 0.0121 - val_loss: 1.4406e-04 - val_accuracy: 0.0000e+00
# Epoch 5/100
#
- val_accuracy: 0.0000e+00
# Epoch 84/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.1963e-04 - accuracy: 0.0121 - val_loss: 1.5724e-04 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.2492e-04 - accuracy: 0.0121 - val_loss: 1.5504e-04 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.1347e-04 - accuracy: 0.0121 - val_loss: 1.5557e-04 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 26/26 [==============================] - 0s 12ms/step - loss: 2.1813e-04 - accuracy: 0.0121 - val_loss: 1.5444e-04 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.2831e-04 - accuracy: 0.0121 - val_loss: 1.7058e-04 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 26/26 [==============================] - 0s 15ms/step - loss: 2.2915e-04 - accuracy: 0.0121 - val_loss: 2.2435e-04 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.3905e-04 - accuracy: 0.0121 - val_loss: 1.4699e-04 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 26/26 [==============================] - 0s 13ms/step - loss: 2.2894e-04 - accuracy: 0.0121 - val_loss: 1.6296e-04 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.3555e-04 - accuracy: 0.0121 - val_loss: 1.6096e-04 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 26/26 [==============================] - 0s 14ms/step - loss: 2.1354e-04 - accuracy: 0.0121 - val_loss: 1.5788e-04 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.1177e-04 - accuracy: 0.0121 - val_loss: 1.5975e-04 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.2029e-04 - accuracy: 0.0121 - val_loss: 2.3645e-04 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.2755e-04 - accuracy: 0.0121 - val_loss: 1.5769e-04 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.2434e-04 - accuracy: 0.0121 - val_loss: 1.6496e-04 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.1425e-04 - accuracy: 0.0121 - val_loss: 1.5200e-04 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.1093e-04 - accuracy: 0.0121 - val_loss: 1.6119e-04 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 26/26 [==============================] - 0s 11ms/step - loss: 2.2853e-04 - accuracy: 0.0121 - val_loss: 1.5080e-04 - val_accuracy: 0.0000e+00
# 29/29 [==============================] - 0s 5ms/step - loss: 2.0927e-04 - accuracy: 0.0109
# SCORE DE TRAIN:
# [0.00020926989964209497, 0.010905125178396702]
# SCORE DE TEST:
# 15/15 [==============================] - 0s 6ms/step - loss: 1.8791e-04 - accuracy: 0.0066
# [0.00018790607282426208, 0.006637168116867542]
# Evaluamos el modelo en train_score: [0.00020926989964209497, 0.010905125178396702]
# 29/29 [==============================] - 1s 4ms/step
# Predecimos con los datos de train: 0.009872516174858443
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.009929878888422247
# 15/15 [==============================] - 0s 3ms/step
#  El  error de la predicion usando datos de test es de : 0.009494785593851607
#  La media de error en la prediccion en test es: 0.009271483187945665
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 0s 5ms/step - loss: 2.0927e-04 - accuracy: 0.0109
# 29/29 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 5ms/step - loss: 1.8791e-04 - accuracy: 0.0066
# 15/15 [==============================] - 0s 3ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_SIN_normalizado_y_con_numero_de_valores_CON_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_3(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_3_GDN(input_shape_Conv2D(5, 3_Conv2D(5, 3_Dense(3_Dense(1_CON_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  
-04 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.0968e-04 - accuracy: 0.0121 - val_loss: 1.5926e-04 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0775e-04 - accuracy: 0.0121 - val_loss: 1.4562e-04 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1733e-04 - accuracy: 0.0121 - val_loss: 1.5963e-04 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1096e-04 - accuracy: 0.0121 - val_loss: 1.4668e-04 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1964e-04 - accuracy: 0.0121 - val_loss: 1.9783e-04 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.2016e-04 - accuracy: 0.0121 - val_loss: 1.5312e-04 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0894e-04 - accuracy: 0.0121 - val_loss: 1.4302e-04 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0892e-04 - accuracy: 0.0121 - val_loss: 1.5479e-04 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0867e-04 - accuracy: 0.0121 - val_loss: 1.4569e-04 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0594e-04 - accuracy: 0.0121 - val_loss: 1.5123e-04 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0994e-04 - accuracy: 0.0121 - val_loss: 1.5468e-04 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1178e-04 - accuracy: 0.0121 - val_loss: 1.4506e-04 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.0945e-04 - accuracy: 0.0121 - val_loss: 1.4554e-04 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.0977e-04 - accuracy: 0.0121 - val_loss: 1.4697e-04 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1263e-04 - accuracy: 0.0121 - val_loss: 2.0259e-04 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.2149e-04 - accuracy: 0.0121 - val_loss: 1.4221e-04 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.1433e-04 - accuracy: 0.0121 - val_loss: 1.4146e-04 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0883e-04 - accuracy: 0.0121 - val_loss: 1.5642e-04 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0711e-04 - accuracy: 0.0121 - val_loss: 1.5328e-04 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.0968e-04 - accuracy: 0.0121 - val_loss: 1.4405e-04 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.1121e-04 - accuracy: 0.0121 - val_loss: 1.4075e-04 - val_accuracy: 0.0000e+00
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9498e-04 - accuracy: 0.0109
# SCORE DE TRAIN:
# [0.00019497692119330168, 0.010905125178396702]
# SCORE DE TEST:
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9592e-04 - accuracy: 0.0066
# [0.00019591515592765063, 0.006637168116867542]
# Evaluamos el modelo en train_score: [0.00019497692119330168, 0.010905125178396702]
# 29/29 [==============================] - 0s 2ms/step
# Predecimos con los datos de train: 0.009759350135145256
# Predecimos con los datos de train_cantidad/dimensiones de datos:(917, 1)
#  La media de error en la prediccion en entrenamiento es: 0.009929878888422247
# 15/15 [==============================] - 0s 2ms/step
#  El  error de la predicion usando datos de test es de : 0.010038051301945045
#  La media de error en la prediccion en test es: 0.009271483187945665
# Mostramos las predicciones de entrenamiento en primera fila y de test en segunda fila:
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9498e-04 - accuracy: 0.0109
# 29/29 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 3ms/step - loss: 1.9592e-04 - accuracy: 0.0066
# 15/15 [==============================] - 0s 2ms/step
# 17
# (17, 54)

# %%
#DAT = sacar_open_5_valores_SIN_normalizado_y_con_numero_de_valores_CON_RETORNO_LOG ()
#x_train, x_test, t_train, t_test =Reordeno_dataset_en_bloques_LAG_dias_y_siguiente_dia_predice_y_split(LAG=11,DAT_1=DAT)
#x_train, x_test = reshape_para_trabajar_conv2D (x_train, x_test)
model, hist = activo_caso_4(x_train, x_test, t_train, t_test)
model_title = 'EJ_8_CASO_4_GDN(input_shape_Conv2D(8_Conv2D(3_MaxPooling2D(_Conv2D(3_MaxPooling2D(2_Dense(1_CON_RETORNO_LOG.'
salida, df = datos_para_comparar_modelos (x_train, t_train, x_test, t_test, model)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  
# Y 
# 'EJ_8_CASO_4_GDN(input_shape_Conv2D(8_Conv2D(3_MaxPooling2D(_Conv2D(3_MaxPooling2D(2_Dense(1__NORMALIZADO_SIN_RETORNO_LOG.'
# CUANDO SE VEN LAS GRAFICAS DE PUNTOS DE LOS T_TRAIN Y T_TEST CONTRA LOS VALORES DE Y_HAT[0].

# %%
# 'EJ_8_CASO_1_GDN(input_shape_Conv2D(10, 3_MaxPooling2D(2_LSTM(5_GRU(5_Dense(1_NORMALIZADO_SIN_RETORNO_LOG.'
# SCORE DE TRAIN:[0.009076726622879505, 0.0010905124945566058]
# SCORE DE TEST:[0.008979814127087593, 0.0]

# 'EJ_8_CASO_2_GDN(input_shape_Conv2D(10,3_GRU(5_LSTM(5_Dense(1_NORMALIZADO_SIN_RETORNO_LOG.'
# SCORE DE TRAIN:[9.355702786706388e-05, 0.0010905124945566058]
# SCORE DE TEST:[9.543544729240239e-05, 0.0]

# 'EJ_8_CASO_3_GDN(input_shape_Conv2D(5, 3_Conv2D(5, 3_Dense(3_Dense(1__NORMALIZADO_SIN_RETORNO_LOG.'
# SCORE DE TRAIN: [0.00014982557331677526, 0.0010905124945566058]
# SCORE DE TEST: [0.00014442518295254558, 0.0]

# 'EJ_8_CASO_4_GDN(input_shape_Conv2D(8_Conv2D(3_MaxPooling2D(_Conv2D(3_MaxPooling2D(2_Dense(1__NORMALIZADO_SIN_RETORNO_LOG.'
# SCORE DE TRAIN:[0.007753442972898483, 0.0010905124945566058]
# SCORE DE TEST:[0.007708757184445858, 0.0]

# 'EJ_8_CASO_1_GDN(input_shape_Conv2D(10, 3_MaxPooling2D(2_LSTM(5_GRU(5_Dense(1_CON_RETORNO_LOG.'
# SCORE DE TRAIN:[0.00021093786926940084, 0.010905125178396702]
# SCORE DE TEST:[0.00018806770094670355, 0.006637168116867542]

# 'EJ_8_CASO_2_GDN(input_shape_Conv2D(10,3_GRU(5_LSTM(5_Dense(1_NORMALIZADO_CON_RETORNO_LOG.'
# SCORE DE TRAIN: [0.00021126861975062639, 0.010905125178396702]
# SCORE DE TEST: [0.00018071822705678642, 0.006637168116867542]

# 'EJ_8_CASO_3_GDN(input_shape_Conv2D(5, 3_Conv2D(5, 3_Dense(3_Dense(1_CON_RETORNO_LOG.'
# SCORE DE TRAIN:[0.0001969866716535762, 0.010905125178396702]
# SCORE DE TEST:[0.00020213818061165512, 0.006637168116867542]

# 'EJ_8_CASO_4_GDN(input_shape_Conv2D(8_Conv2D(3_MaxPooling2D(_Conv2D(3_MaxPooling2D(2_Dense(1_CON_RETORNO_LOG.'
# SCORE DE TRAIN:[0.00021227342949714512, 0.010905125178396702]
# SCORE DE TEST:[0.00018151095719076693, 0.006637168116867542]

# SE VE QUE LOS MODELOS CON_RETORNO_LOG DAN MEJORE VALORES QUE LOS NORMALIZADO_SIN_RETORNO_LOG
# A EXCEPCION DEL CASO2. Y SE QUE LOS 4 EJEMPLOS DE CON_RETORNO_LOG DAN LOSS EN TEST PARECIDOS
